# %% [markdown]
# task 1

# %%
if __name__ =='__main__':
    print(input()[::-1])
# Out:
# qwerty
# ytrewq

# %% [markdown]
# task 2

# %%
if __name__ =='__main__':
  numb =  [int(i)  for i in input().split()]
  a = -1
  for i in range(len(numb)):
    print(numb[a],end=' ')
    a -= 1
# Out:
# 123 4
# 4 123

# %% [markdown]
# tast 3

# %%
if __name__ =='__main__':
  x = int(input())
  for i in range(x):
    print('*' * x)
# Out:
# 4
# ****
# ****
# ****
# ****

# %% [markdown]
# task 4

# %%
if __name__ =='__main__':
  x = [int(i)  for i in input()]
  a = 0
  for i in range(len(x)):
    if x[i] % 2 == 0:
    print(x[i],end='')
    print(x[a],end='')
    a += 2
# Out:
# 123456
# 214365

# %% [markdown]
# task 5

# %%
if __name__ =='__main__':
  first_value = [int(i)  for i in input()]
  second_value = [int(i)  for i in input()]
  for i in range(len(first_value)):
    print((first_value[i] + second_value[i]) % 10,end='')
# Out:
# 405
# 839
# 234

# %% [markdown]
# task 6

# %%
if __name__ =='__main__':
    red_count = int(input())
    green_count = int(input())
    blue_count = int(input())
    print(red_count + blue_count + 1)
# Out:
# 1
# 2
# 3
# 5

# %% [markdown]
# task 7

# %%
if __name__ =='__main__':
    a = int(input())
    b = int(input())
    c = int(input())
    print(abs(a-b)/c)
# Out:
# 10
# 32
# 5
